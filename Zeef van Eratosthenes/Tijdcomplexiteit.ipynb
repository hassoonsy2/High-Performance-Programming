# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('speed.xlsx',converters={'Tijd in sec(Alleen Omp': decimal_from_value})

# %%
data.columns
# Out:
# Index(['Aantal Threads ', 'Tijd in sec(Alleen Omp',
#        'Tijd in sec ( MPI & OMP)'],
#       dtype='object')

# %%
data
# Out:
#    Aantal Threads                              Tijd in sec(Alleen Omp  \
# 0                1  22.9179999999999992610355548094958066940307617...
# 1                2   17.844999999999998863131622783839702606201171875
# 2                4  15.9350000000000004973799150320701301097869873...
# 3                8  16.9959999999999986641796567710116505622863769...
#
#    Tijd in sec ( MPI & OMP)
# 0                    21.889
# 1                    16.670
# 2                    15.310
# 3                    16.859

# %%
x = data['Aantal Threads ']


plt.figure(figsize=(15,10), dpi=100)
plt.plot(x ,data['Tijd in sec ( MPI & OMP)'], '-')
plt.plot(x ,data['Tijd in sec(Alleen Omp'], '-')
plt.xlabel('Aantal Threads', fontsize=15)
plt.ylabel('Tijd in Sec', fontsize=15)
plt.legend(['Alleen OMP', 'OMP & MPI'])
plt.title("Tijdscomplexiteit ", fontsize=15)
plt.show()
