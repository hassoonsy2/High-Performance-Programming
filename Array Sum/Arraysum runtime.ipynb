# %% [markdown]
# ## Student : Hussin Almoustafa
# ## Studentnummer : 1776495
#
# Hieronder is de runtime van de code :
#
#
#
# - 10K:
# ![image-2.png](attachment:image-2.png)
#
# - 100K:
# ![image.png](attachment:image.png)
#
#
# - 1M:
# ![image-3.png](attachment:image-3.png)
#
# - 10M:
# ![image-4.png](attachment:image-4.png)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sum.csv',sep=';')

# %%
data
# Out:
#    10000  100000  1000000  10000000
# 0  0.002   0.001    0.002     0.007

# %%
data.astype(float, copy=True, errors='raise')
# Out:
#    10000  100000  1000000  10000000
# 0  0.002   0.001    0.002     0.007

# %%
data.boxplot(grid=False, rot=45, fontsize=15)
# Out:
# <AxesSubplot:>
